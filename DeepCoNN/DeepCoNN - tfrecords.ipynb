# %%
import numpy as np
import pandas as pd
import pickle as pkl
import tensorflow as tf
import time
# Out:
# /home/michael/dlprof/venv/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
def model_fn(features, labels, mode):
    emb_size = 50
    filters=10
    kernel_size=3
    
    with open("../data/dictionary.pkl", "rb") as f:
        dictionary = pkl.load(f)
    
    values = list(range(len(dictionary)))
    keys = list(dictionary)
    
    table = tf.contrib.lookup.HashTable(
      tf.contrib.lookup.KeyValueTensorInitializer(keys, values), -1
    )
    
    word_embeddings = tf.get_variable(
        "word_embeddings",
        shape=[len(dictionary), emb_size]
    )
    
    u_inputs = features[0]
    i_inputs = features[1]
    
    u_inputs = table.lookup(u_inputs)
    i_inputs = table.lookup(i_inputs)

    u_inputs = tf.nn.embedding_lookup(word_embeddings, u_inputs)
    i_inputs = tf.nn.embedding_lookup(word_embeddings, i_inputs)
    
    user_conv1 = tf.layers.conv1d(
        u_inputs,
        filters,
        kernel_size,
        use_bias=True,
        activation=tf.nn.tanh,
        name="user_conv")

    item_conv1 = tf.layers.conv1d(
        i_inputs,
        filters,
        kernel_size,
        use_bias=True,
        activation=tf.nn.tanh,
        name="item_conv")

    user_max_pool1 = tf.layers.max_pooling1d(user_conv1, 2, 1)
    item_max_pool1 = tf.layers.max_pooling1d(item_conv1, 2, 1)

    user_flat = tf.layers.flatten(user_max_pool1)
    item_flat = tf.layers.flatten(item_max_pool1)

    user_dense = tf.layers.dense(user_flat, 64, activation=tf.nn.relu)
    item_dense = tf.layers.dense(item_flat, 64, activation=tf.nn.relu)
    
    predictions = tf.reduce_sum( tf.multiply( user_dense, item_dense ), 1, keep_dims=True )
    
    output = {
        "rating": predictions,
        "user_review_embedding": user_flat,
        "item_review_embedding": item_flat
    }
    
    if mode == tf.estimator.ModeKeys.PREDICT:
        return tf.estimator.EstimatorSpec(mode=mode, predictions=predictions)


    # Calculate Loss (for both TRAIN and EVAL modes)
    loss = tf.losses.mean_squared_error(labels, predictions)

    # Configure the Training Op (for TRAIN mode)
    if mode == tf.estimator.ModeKeys.TRAIN:
        optimizer = tf.train.AdamOptimizer(learning_rate=0.0001)
        train_op = optimizer.minimize(
            loss=loss,
            global_step=tf.train.get_global_step())
        return tf.estimator.EstimatorSpec(mode=mode, loss=loss, train_op=train_op)

    # Add evaluation metrics (for EVAL mode)
    eval_metric_ops = {
        "mean square error": tf.metrics.mean_squared_error(
            labels=labels, predictions=predictions)
    }
    return tf.estimator.EstimatorSpec(
        mode=mode, loss=loss, eval_metric_ops=eval_metric_ops)

# %% [markdown]
# # Test Forward

# %%
truncate_len = 800
batch_size = 32

# %%
def get_truncate_fn(trunc_len):
    def truncate_fn(user, item, rating):
        return user[:trunc_len], item[:trunc_len], rating
    return truncate_fn

# %%
def split_fn(user, item, rating):
    user = tf.string_split(user)
    item = tf.string_split(item)
    return user.values, item.values, rating

# %%
def parse_fn(record):
    features = {
            "user_review": tf.FixedLenSequenceFeature([], tf.string, allow_missing=True),
            "item_review": tf.FixedLenSequenceFeature([], tf.string, allow_missing=True),
            "rating": tf.FixedLenFeature([1], tf.float32)
        }
    parsed_features = tf.parse_single_example(record, features)
    return parsed_features["user_review"], parsed_features["item_review"], parsed_features["rating"]

# %%
def get_dataset_iterator(loc, batch_size, max_len, pad_value):
    dataset = tf.data.TFRecordDataset(loc)
    dataset = dataset.prefetch(batch_size)
    dataset = dataset.map(parse_fn, num_parallel_calls=batch_size)
    dataset = dataset.map(split_fn, num_parallel_calls=batch_size)
    dataset = dataset.map(get_truncate_fn(max_len), num_parallel_calls=batch_size)
    dataset = dataset.padded_batch(batch_size, padded_shapes=([max_len], [max_len], [None]), padding_values=(pad_value, pad_value, 0.0))
    dataset = dataset.shuffle(26352, reshuffle_each_iteration=False)
    iterator = dataset.make_one_shot_iterator()
    return iterator

# %%
def train_input_fn():
    train_dataset = get_dataset_iterator(
        loc="../data/train.tfrecords",
        batch_size=batch_size,
        max_len=truncate_len,
        pad_value="unk")
    nex = train_dataset.get_next()
    return (nex[0], nex[1]), tf.cast(nex[2], tf.int32)

# %%
def test_input_fn():
    test_dataset = get_dataset_iterator(
        loc="../data/test.tfrecords",
        batch_size=batch_size,
        max_len=truncate_len,
        pad_value="unk"
    )
    nex = test_dataset.get_next()
    return (nex[0], nex[1]), nex[2]

# %%
scoring_function = tf.estimator.Estimator(
    model_fn=model_fn,
    model_dir="output/model_" + str(int(time.time())))
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_num_ps_replicas': 0, '_log_step_count_steps': 100, '_is_chief': True, '_num_worker_replicas': 1, '_task_id': 0, '_save_checkpoints_steps': None, '_task_type': 'worker', '_save_checkpoints_secs': 600, '_evaluation_master': '', '_keep_checkpoint_max': 5, '_train_distribute': None, '_save_summary_steps': 100, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': 'output/model_1525108123', '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fd1dc671940>, '_session_config': None, '_tf_random_seed': None, '_global_id_in_cluster': 0, '_service': None, '_master': ''}

# %%
# from tensorflow.python import debug as tf_debug
# hook = tf_debug.TensorBoardDebugHook("localhost:6060")
times = []
for i in range(5):
    s = time.time()
    scoring_function.train(input_fn=train_input_fn) # , hooks=[hook])
    e = time.time()
    runtime = e - s
    print("ran {} seconds".format(runtime))
    times.append(runtime)
print("average runtime: {}".format(np.mean(times)))
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From <ipython-input-2-1cbda9713abb>:55: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into output/model_1525108123/model.ckpt.
# INFO:tensorflow:loss = 21.024988, step = 0
# INFO:tensorflow:global_step/sec: 75.8136
# INFO:tensorflow:loss = 3.0073333, step = 100 (1.320 sec)
# INFO:tensorflow:global_step/sec: 87.6885
# INFO:tensorflow:loss = 2.7943685, step = 200 (1.141 sec)
# INFO:tensorflow:global_step/sec: 86.3998
# INFO:tensorflow:loss = 1.2933428, step = 300 (1.157 sec)
# INFO:tensorflow:global_step/sec: 88.2546
# INFO:tensorflow:loss = 1.0739632, step = 400 (1.133 sec)
# INFO:tensorflow:global_step/sec: 86.7545
# INFO:tensorflow:loss = 0.79262495, step = 500 (1.153 sec)
# INFO:tensorflow:global_step/sec: 87.6714
# INFO:tensorflow:loss = 0.46428105, step = 600 (1.141 sec)
# INFO:tensorflow:global_step/sec: 88.2807
# INFO:tensorflow:loss = 1.7737885, step = 700 (1.133 sec)
# INFO:tensorflow:global_step/sec: 88.777
# INFO:tensorflow:loss = 0.97237754, step = 800 (1.126 sec)
# INFO:tensorflow:Saving checkpoints for 824 into output/model_1525108123/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.0222906.
# ran 24.929840564727783 seconds
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from output/model_1525108123/model.ckpt-824
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 825 into output/model_1525108123/model.ckpt.
# INFO:tensorflow:loss = 0.9394999, step = 824
# INFO:tensorflow:global_step/sec: 76.0074
# INFO:tensorflow:loss = 1.4068596, step = 924 (1.317 sec)
# INFO:tensorflow:global_step/sec: 89.4166
# INFO:tensorflow:loss = 1.3736796, step = 1024 (1.119 sec)
# INFO:tensorflow:global_step/sec: 88.0205
# INFO:tensorflow:loss = 0.8945606, step = 1124 (1.136 sec)
# INFO:tensorflow:global_step/sec: 88.5634
# INFO:tensorflow:loss = 1.0821309, step = 1224 (1.129 sec)
# INFO:tensorflow:global_step/sec: 87.14
# INFO:tensorflow:loss = 1.3346525, step = 1324 (1.148 sec)
# INFO:tensorflow:global_step/sec: 86.684
# INFO:tensorflow:loss = 0.7115187, step = 1424 (1.153 sec)
# INFO:tensorflow:global_step/sec: 88.3551
# INFO:tensorflow:loss = 0.6351538, step = 1524 (1.132 sec)
# INFO:tensorflow:global_step/sec: 88.2397
# INFO:tensorflow:loss = 0.6143103, step = 1624 (1.133 sec)
# INFO:tensorflow:Saving checkpoints for 1648 into output/model_1525108123/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.2715855.
# ran 19.23182249069214 seconds
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from output/model_1525108123/model.ckpt-1648
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1649 into output/model_1525108123/model.ckpt.
# INFO:tensorflow:loss = 0.828374, step = 1648
# INFO:tensorflow:global_step/sec: 79.7629
# INFO:tensorflow:loss = 1.9823166, step = 1748 (1.255 sec)
# INFO:tensorflow:global_step/sec: 89.3449
# INFO:tensorflow:loss = 0.6073493, step = 1848 (1.119 sec)
# INFO:tensorflow:global_step/sec: 89.3828
# INFO:tensorflow:loss = 0.7179184, step = 1948 (1.120 sec)
# INFO:tensorflow:global_step/sec: 87.7531
# INFO:tensorflow:loss = 0.99926853, step = 2048 (1.138 sec)
# INFO:tensorflow:global_step/sec: 86.4693
# INFO:tensorflow:loss = 1.1549717, step = 2148 (1.156 sec)
# INFO:tensorflow:global_step/sec: 87.1026
# INFO:tensorflow:loss = 1.6947868, step = 2248 (1.148 sec)
# INFO:tensorflow:global_step/sec: 87.2489
# INFO:tensorflow:loss = 1.5726985, step = 2348 (1.146 sec)
# INFO:tensorflow:global_step/sec: 87.7957
# INFO:tensorflow:loss = 0.8741206, step = 2448 (1.139 sec)
# INFO:tensorflow:Saving checkpoints for 2472 into output/model_1525108123/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.32200992.
# ran 19.396844625473022 seconds
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from output/model_1525108123/model.ckpt-2472
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 2473 into output/model_1525108123/model.ckpt.
# INFO:tensorflow:loss = 1.243599, step = 2472
# INFO:tensorflow:global_step/sec: 73.695
# INFO:tensorflow:loss = 0.7971037, step = 2572 (1.358 sec)
# INFO:tensorflow:global_step/sec: 88.3424
# INFO:tensorflow:loss = 0.8643744, step = 2672 (1.132 sec)
# INFO:tensorflow:global_step/sec: 87.0355
# INFO:tensorflow:loss = 0.7171742, step = 2772 (1.149 sec)
# INFO:tensorflow:global_step/sec: 86.1384
# INFO:tensorflow:loss = 0.6696403, step = 2872 (1.161 sec)
# INFO:tensorflow:global_step/sec: 87.619
# INFO:tensorflow:loss = 0.6856096, step = 2972 (1.141 sec)
# INFO:tensorflow:global_step/sec: 85.6861
# INFO:tensorflow:loss = 0.80911696, step = 3072 (1.167 sec)
# INFO:tensorflow:global_step/sec: 85.324
# INFO:tensorflow:loss = 0.12247605, step = 3172 (1.172 sec)
# INFO:tensorflow:global_step/sec: 86.1067
# INFO:tensorflow:loss = 0.573797, step = 3272 (1.162 sec)
# INFO:tensorflow:Saving checkpoints for 3296 into output/model_1525108123/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.7590199.
# ran 20.40223240852356 seconds
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from output/model_1525108123/model.ckpt-3296
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 3297 into output/model_1525108123/model.ckpt.
# INFO:tensorflow:loss = 0.7795686, step = 3296
# INFO:tensorflow:global_step/sec: 77.7933
# INFO:tensorflow:loss = 0.905006, step = 3396 (1.287 sec)
# INFO:tensorflow:global_step/sec: 87.5772
# INFO:tensorflow:loss = 0.5607634, step = 3496 (1.142 sec)
# INFO:tensorflow:global_step/sec: 87.1517
# INFO:tensorflow:loss = 0.6601967, step = 3596 (1.147 sec)
# INFO:tensorflow:global_step/sec: 85.6552
# INFO:tensorflow:loss = 0.44633228, step = 3696 (1.167 sec)
# INFO:tensorflow:global_step/sec: 86.6992
# INFO:tensorflow:loss = 1.00386, step = 3796 (1.153 sec)
# INFO:tensorflow:global_step/sec: 85.6338
# INFO:tensorflow:loss = 0.4155901, step = 3896 (1.168 sec)
# INFO:tensorflow:global_step/sec: 86.5826
# INFO:tensorflow:loss = 0.78619957, step = 3996 (1.155 sec)
# INFO:tensorflow:global_step/sec: 87.0535
# INFO:tensorflow:loss = 0.6942558, step = 4096 (1.149 sec)
# INFO:tensorflow:Saving checkpoints for 4120 into output/model_1525108123/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.18938589.
# ran 19.432084321975708 seconds
# average runtime: 20.678564882278444
